# %% [markdown]
# # Homework 4:
#
# **DUE:** 5pm EST, Feb 27, 2020

# %% [markdown]
# ### **Conceptual:** Short answer questions. Be concise

# %% [markdown]
# ---
#
# 1.Using the mean squared error (MSE) as your objective function allows for a closed form solution to finding the maximum likelihood estimate (MLE) of your model parameters in linear regression. Let’s consider the simple, single predictor variable model $Y= \beta_0 + \beta_1 X $.
#
# a) Use algebra to show how you can expand out the MSE to get from i to ii below. Do your proof using Latex equation formatting.

# %% [markdown]
#  _i)_ $MSE(\beta_0, \beta_1)=E[ (Y-(\beta_0 + \beta_1 X))^2]$
#
#  _ii)_ $MSE(\beta_0, \beta_1)=E[Y^2] -2 \beta_0E[Y]-2 \beta_1 Cov[X,Y]-2 \beta_1 E[X]E[Y]+ \beta_0^2 +2 \beta_0 \beta_1 E[X]+\beta_1^2 Var[X]+ \beta_1^2 (E[X])^2$

# %% [markdown]
# **Answer:**

# %% [markdown]
# >$= E[(Y - (\beta_0 + \beta_1X))(Y - (\beta_0 + \beta_1X))]$
#
# >$= E[Y^2 - 2Y(\beta_0+\beta_1X) + (\beta_0+\beta_1X)^2$
#
# >$= E[Y^2 -  2Y\beta_0 - 2\beta_1XY + \beta_0^2 + 2\beta_0\beta_1X + \beta_1^2X^2]$
#
# >$= E[Y^2] - 2\beta_0E[Y] - 2\beta_1E[XY] + \beta_0^2 + 2\beta_0\beta_1E[X] + \beta_1^2E[X^2]$
#
# >$= E[Y^2] - 2\beta_0E[Y] - 2\beta_1(Cov[XY]+E[X]E[Y]) + \beta_0^2 + 2\beta_0\beta_1E[X] + \beta_1^2(Var[X] + E[X]^2)$
#
# >$= E[Y^2] - 2\beta_0 E[Y] - 2\beta_1Cov[XY] - 2\beta_1E[X]E[Y] + \beta_0^2 + 2\beta_0\beta_1E[X] + \beta_1^2Var[X] + \beta_1^2(E[X])^2$

# %% [markdown]
# b) Prove that the MLE of $\beta_0$ is $E[Y]- \beta_1 E[X]$ by taking the derivative of _ii_ above, with respect to $\beta_0$, setting the derivative to zero, and solving for $\beta_0$.

# %% [markdown]
# **Answer:**
#
#
# - **Taking the partial derivative with respect to $\beta_0$:**
#
#
# $$\frac{\partial E[(Y-(\beta_0 + \beta_1 X))^2]}{\partial \beta_0}$$
#
#
# >$$= \frac{\partial (E[Y^2] - 2\beta_0 E[Y] - 2\beta_1Cov[XY] - 2\beta_1E[X]E[Y] + \beta_0^2 + 2\beta_0\beta_1E[X] + \beta_1^2Var[X] + \beta_1^2(E[X])^2)}{\partial \beta_0}$$
#
#
# >$= - 2\beta_0 E[Y] + \beta_0^2 + 2\beta_0\beta_1E[X]$
#
#
# >$= - 2E[Y] + 2\beta_0 + 2\beta_1E[X]$
#
#
#
# - **Solving for $\beta_0$:**
#
# >$0= - 2E[Y] + 2\beta_0 + 2\beta_1E[X]$
#
# >$-2\beta_0 = - 2E[Y] + 2\beta_1E[X]$
#
# >$\beta_0 = E[Y] - \beta_1E[X]$

# %% [markdown]
# c) Prove that the MLE for $\beta_1$ is $Cov[X,Y]/Var[X]$ by taking the derivative of _ii_ above, with respect to $\beta_1$, setting the derivative to zero, and solving for $\beta_1$.

# %% [markdown]
# **Answer:**
#
# - **Taking the partial derivative with respect to $\beta_1$:**
#
#
# $$\frac{\partial E[(Y-(\beta_0 + \beta_1 X))^2]}{\partial \beta_1} $$
#
#
# >$$= \frac{\partial (E[Y^2] - 2\beta_0 E[Y] - 2\beta_1Cov[XY] - 2\beta_1E[X]E[Y] + \beta_0^2 + 2\beta_0\beta_1E[X] + \beta_1^2Var[X] + \beta_1^2(E[X])^2)}{\partial \beta_1}$$
#
# >$=  - 2\beta_1Cov[XY] - 2\beta_1E[X]E[Y] + 2\beta_0\beta_1E[X] + \beta_1^2Var[X] + \beta_1^2(E[X])^2$
#
# >$=  - 2Cov[XY] - 2E[X]E[Y] + 2\beta_0E[X] + 2\beta_1Var[X] + 2\beta_1(E[X])^2$
#
#
# - **Solving for $\beta_1$:**
#
# >$0 =  - 2Cov[XY] - 2E[X]E[Y] + 2\beta_0E[X] + 2\beta_1Var[X] + 2\beta_1(E[X])^2$
#
# >$- 2\beta_1Var[X] - 2\beta_1(E[X])^2 =  - 2Cov[XY] - 2E[X]E[Y] + 2\beta_0E[X]$
#
# >$- 2\beta_1Var[X] - 2\beta_1(E[X])^2 =  - 2Cov[XY] - 2E[X]E[Y] + 2(E[Y] - \beta_1E[X])E[X]$
#
# >$- 2\beta_1Var[X] - 2\beta_1(E[X])^2 =  - 2Cov[XY] - 2E[X]E[Y] + (2E[Y] - 2\beta_1E[X])E[X]$
#
# >$- 2\beta_1Var[X] - 2\beta_1(E[X])^2 =  - 2Cov[XY] - 2E[X]E[Y] + 2E[X]E[Y] - 2\beta_1(E[X])^2$
#
# >$- 2\beta_1Var[X] - 2\beta_1(E[X])^2 =  - 2Cov[XY] - 2\beta_1(E[X])^2$
#
# >$- 2\beta_1Var[X]=  - 2Cov[XY]$
#
# >$\beta_1Var[X]= Cov[XY]$
#
# >$\beta_1= Cov[XY]/Var[X]$

# %% [markdown]
# ---
#
# 2.Using the MLE solutions shown in 1(b) and 1(c) above, show how, in the case of simple linear regression, the least squares line always passes through the point $(E(X), E(Y))$ or $(x,y)$). What does this imply about the leverage that the response and predictor variable means have on the ordinary least squares solution?

# %% [markdown]
# **Answer:**
#
# >In the case a regression line represented by the equation $Y = \beta_0 + \beta_1X$ solving for $\beta_0$ gives $\beta_0 = Y - \beta_1X $. Given that the MLE solution for $\beta_0$ was $\beta_0 = E[Y] - \beta_1E[X]$, we know that the regression line must always pass through point $(E[X], E[Y])$. That is, given out MLE solution for $\beta_0$, plugging in $E[X]$ into our regression line equation (for $X$) will yield $E[Y]$ (for $Y$).
# This implies that the ordinary least squares solution, and thus parameters the best fitting regression line, is contingent upon/determined according to or with respect to the means of $X$ and $Y$.

# %% [markdown]
# ---
# 3.In the case where X and Y are standard normal variables (i.e. $N(0,1)$), show that the ordinary least squares solution converges to the same solution as the Pearson correlation coefficient $r=Cov[X,Y]/(\sigma_X * \sigma_Y)$. What exactly do they both converge to?

# %% [markdown]
# **Answer:**
#
# ### Given that $X~N(0,1)$ and $Y~N(0,1)$,
# ### And given that $E[X]=\bar{X}$ and $E[Y]=\bar{Y}$,
# ### then $E[X]=0$ and $E[Y]=0$ and $\sigma_X=1$ and $\sigma_Y=1$**
#
# ### ***So:***
#
# >$r=Cov[X,Y]/(\sigma_X * \sigma_Y)$
#
# >$r= Cov[X,Y]/(1 * 1)$
#
# >$r= Cov[X,Y]$
#
#
# ---
#
# >$\beta_0 = E[Y] - \beta_1E[X]$
#
# >$\beta_0 = 0 - \beta_10$
#
# >$\beta_0 = 0$
#
# ---
#
# >$\beta_1= Cov[XY]/Var[X]$
#
# >$\beta_1= Cov[XY]/1$
#
# >$\beta_1= Cov[XY]$
#
#
# **And since, $r=Cov[X,Y]=\beta_1$, both solutions converge to $Cov[X,Y]$.**

# %% [markdown]
# ---
#
# 4.Three methods for evaluating a regression model’s performance are $r^2$, $RSE$, and the $F$ Test. Show the functional form of each method and describe conceptually what it is telling you about your model.

# %% [markdown]
# **Answer:**
#
#
# **$R^2$**
#
# $$ r^2 = \frac{TSS-RSS}{TSS} = 1 - \frac{RSS}{TSS} = 1 - \frac{\sum_{i=1}^{n} (y_i - \hat{y}_i)^2} {\sum_{i=1}^{n} (y_i - \bar{y})^2}$$
#
# >**The value for $R^2$ reflects the percent of variance in your response varirable explained by your model.**
#
#
# **$RSE$**
#
# $$ RSE = \sigma_{model}^2 = \sqrt{ \frac{RSS}{n-2} } = \sqrt{ \frac{ \sum_{i=1}^{n} (y_i-\hat{y_i})^2 }{n-2} }$$
#
# >**RSE is a value that reflects the variance in our model and allows us to estimate our confidence on our model fit. Lower RSE indicates a better fit.**
#
#
# **$F$**
#
# $$F = \frac{ \frac{(TSS-RSS)}{p}} { \frac{RSS}{n - p - 1}}$$
#
# \
# $$= \frac{(\frac{1}{p}) \sum_{i=1}^{n}(y_i-\bar{y})^2 - \sum_{i=1}^{n}(y_i-\hat{y}_i)^2}{{(\frac{1}{n - p - 1})} \sum_{i=1}^{n} (y_i-\hat{y}_i)^2}$$
#
# >**The F statistic is a ratio that indicates how much TSS (total variance in your response variable)is explained in the error/variance in your model. If you have a good model fit, error in your model is low, and therefore RSS is low. Consequently, the F statistic will be high.**

# %% [markdown]
# ---
#
# ### **Applied:** Show your code & plots
#
# We will use the HCP dataset (see Homework 2) for these problems. Include conceptual answers to questions as comments in code cells.

# %% [markdown]
# 5.Here we will look at how different measures including gender, gray matter volume, and white matter volume can associate with the unadjusted flanker task score
#
# (a) Load the HCP data set and subset the data by selecting only the Subject, Gender, Flanker-Unadj, FS_Tot_WM_Vol and FS_Total_GM_Vol columns.

# %%
# -------------------------------
# Question 5(a)
# -------------------------------
library(tidyverse)
setwd("/Users/Debbie/Documents/DOCUMENTS/CLASSES/DSPAN/GitHub/Bitran_DSPN_S20/Homeworks")
hcp.d <- read_csv("unrestricted_trimmed_1_7_2020_10_50_44.csv")
hcp.d <- select(hcp.d, Subject, Gender, Flanker_Unadj, FS_Tot_WM_Vol, FS_Total_GM_Vol)
head(hcp.d)
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Release = col_character(),
#   Acquisition = col_character(),
#   Gender = col_character(),
#   Age = col_character(),
#   PSQI_BedTime = col_time(format = ""),
#   PSQI_GetUpTime = col_time(format = ""),
#   NEORAW_01 = col_character(),
#   NEORAW_02 = col_character(),
#   NEORAW_03 = col_character(),
#   NEORAW_04 = col_character(),
#   NEORAW_05 = col_character(),
#   NEORAW_06 = col_character(),
#   NEORAW_07 = col_character(),
#   NEORAW_08 = col_character(),
#   NEORAW_09 = col_character(),
#   NEORAW_10 = col_character(),
#   NEORAW_11 = col_character(),
#   NEORAW_12 = col_character(),
#   NEORAW_13 = col_character(),
#   NEORAW_14 = col_character()
#   # ... with 46 more columns
# )
#
# See spec(...) for full column specifications.
#   Subject Gender Flanker_Unadj FS_Tot_WM_Vol FS_Total_GM_Vol
# 1 100004  M      121.97            NA            NA
# 2 100206  M      130.42        543134        807245
# ...

# %% [markdown]
# (b) Fit a simple linear regression model with unadjusted Flanker task scores as the repsonse variable (i.e., Y) and total grey matter volume as the predictor variable (i.e., X). Show the summary of the model, extract the coefficients and the confidence intervals, and report what inference you would make based on these numbers.

# %%
# -------------------------------
# Question 5(b)
# -------------------------------
model1 <- lm(Flanker_Unadj ~ FS_Total_GM_Vol, data=hcp.d)
summary(model1)
cbind(coef(model1), confint(model1))

##Based on these statistics, we could infer that there is a statistically significant, positive 
#relationship between gray matter volume and raw flanker scores. 
#However the regression coefficient for gray matter volume suggests that the magnitude of this
#relationship is rather small (one unit increase in GM volume corresponds to a pretty neglible
#increase in raw flanker score.)
#The confindence interval around our coefficient does not contain zero, indicating that
#if we did this experiment many many times across many samples, 
#there is a 95% probability that our coeficient values will fall in this range
#Of note, our CI is pretty tight/narrow, which is likely a result of having a 
#large sample size.
# Out:
# Call:
# lm(formula = Flanker_Unadj ~ FS_Total_GM_Vol, data = hcp.d)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -28.2280  -6.5969  -0.0119   6.5497  31.0108
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     9.026e+01  3.041e+00  29.677  < 2e-16 ***
# FS_Total_GM_Vol 3.110e-05  4.412e-06   7.048 3.18e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.864 on 1111 degrees of freedom
#   (93 observations deleted due to missingness)
# Multiple R-squared:  0.0428,	Adjusted R-squared:  0.04194
# F-statistic: 49.68 on 1 and 1111 DF,  p-value: 3.177e-12
#                              2.5 %        97.5 %
# (Intercept)     9.025646e+01 8.428917e+01 9.622375e+01
# FS_Total_GM_Vol 3.109965e-05 2.244198e-05 3.975733e-05

# %% [markdown]
# (c) Generate all the residual plots to check whether the fit model meets our assumptions. Then generate a scatter plot with *ggplot*, using *geom_smooth*, to show the residuals and check our assumptions. Does it look like the data is meeting the assumptions of linear regression. Why or why not?

# %%
# -------------------------------
# Question 5(c)
# -------------------------------
plot(model1)
#Based on our residual plots, the data generally seems to be 
#meeting the assumptions of linear regression. 
#The Q-Q plot trails off a little bit at the ends, though.
#Also from the gg-plot of the residual lines (and from the R-squared for our model = 4.28%) 
#we can see that there is still quite a bit of unexplained variance in our response variable. 

hcp.d$predicted <- predict(model1, hcp.d)

ggplot( hcp.d, aes(x = FS_Total_GM_Vol, y = Flanker_Unadj)) +
  geom_smooth(method = "lm", se = TRUE, color = "green") +  
  geom_segment(aes(xend = FS_Total_GM_Vol, yend = predicted), alpha = .2) +  
  geom_point() +
  geom_point(aes(y = predicted), shape = 1)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Warning message:
# “Removed 93 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 93 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 93 rows containing missing values (geom_point).”
# Warning message:
# “Removed 93 rows containing missing values (geom_point).”
# Plot with title “”
# plot without title

# %% [markdown]
# 6.Here we will ask about the same associations between the grey matter volume and Flanker task performance, but from a prediction perspective. Let's say you collected more data for 5 more participants and you get their total grey matter volume as follows: 612432, 702562, 596433, 695982, 649230. Predict what their unadjusted Flanker score is going to be based on the model that we just fit. Store all the values and CI bounds in a data frame called *predicted_table* .

# %%
# -------------------------------
# Question 6
# -------------------------------
GMVol_input <- data.frame(FS_Total_GM_Vol=c(612432, 702562, 596433, 695982, 649230))
predicted_table <- data.frame(predict(model1, GMVol_input, interval = 'confidence'))
predicted_table <- cbind(GMVol_input,predicted_table)
colnames(predicted_table) = c('FS_Total_GM_Vol','Flanker_Unadj_pred', 'lower_CI_bound', 'upper_CI_bound')
predicted_table
# Out:
#   FS_Total_GM_Vol Flanker_Unadj_pred lower_CI_bound upper_CI_bound
# 1 612432          109.3029           108.4415       110.1643
# 2 702562          112.1059           111.5083       112.7035
# 3 596433          108.8053           107.8370       109.7736
# 4 695982          111.9013           111.3147       112.4878
# 5 649230          110.4473           109.7856       111.1089

# %% [markdown]
# 7.Now we can explore main effects and interactions
#
# (a) Fit a multiple regression model with the unadjusted Flanker scores as the response variable and white matter volume, grey matter volume, and gender included as main effect terms (i.e., predictor variables).

# %%
# -------------------------------
# Question 7(a)
# -------------------------------
#
model2 <- lm(Flanker_Unadj ~ Gender + FS_Tot_WM_Vol + FS_Total_GM_Vol, data=hcp.d)
summary(model2)
cbind(coef(model2), confint(model2))
# Out:
# Call:
# lm(formula = Flanker_Unadj ~ Gender + FS_Tot_WM_Vol + FS_Total_GM_Vol,
#     data = hcp.d)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -28.1451  -6.5563  -0.0072   6.4591  31.1901
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      9.190e+01  3.758e+00  24.455  < 2e-16 ***
# GenderM          7.033e-01  7.797e-01   0.902 0.367235
# FS_Tot_WM_Vol   -8.510e-06  9.894e-06  -0.860 0.389914
# FS_Total_GM_Vol  3.376e-05  8.814e-06   3.830 0.000135 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.866 on 1109 degrees of freedom
#   (93 observations deleted due to missingness)
# Multiple R-squared:  0.04403,	Adjusted R-squared:  0.04144
# F-statistic: 17.02 on 3 and 1109 DF,  p-value: 8.167e-11
#                               2.5 %         97.5 %
# (Intercept)      9.189731e+01  8.452406e+01 9.927056e+01
# GenderM          7.033386e-01 -8.265658e-01 2.233243e+00
# ...

# %% [markdown]
# (b) Now update the model with gender and white matter volume removed. What has changed?

# %%
# -------------------------------
# Question 7(b)
# -------------------------------
model2_update <- update(model2, ~.-Gender -FS_Tot_WM_Vol)
summary(model2_update)
cbind(coef(model2_update), confint(model2_update))

#The F statistic increased quite a bit from the previous model which indicates 
#that this updated model has much less variance and is probably a better fit for our data. 
#Also,  our R-squared increased when removing those two terms, although only marginally).
#Nevertheless this further suggests that including Gender and total white matter 
#negatively impacts our model fit performance.
# Out:
# Call:
# lm(formula = Flanker_Unadj ~ FS_Total_GM_Vol, data = hcp.d)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -28.2280  -6.5969  -0.0119   6.5497  31.0108
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     9.026e+01  3.041e+00  29.677  < 2e-16 ***
# FS_Total_GM_Vol 3.110e-05  4.412e-06   7.048 3.18e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.864 on 1111 degrees of freedom
#   (93 observations deleted due to missingness)
# Multiple R-squared:  0.0428,	Adjusted R-squared:  0.04194
# F-statistic: 49.68 on 1 and 1111 DF,  p-value: 3.177e-12
#                              2.5 %        97.5 %
# (Intercept)     9.025646e+01 8.428917e+01 9.622375e+01
# FS_Total_GM_Vol 3.109965e-05 2.244198e-05 3.975733e-05

# %% [markdown]
# (c) Construct a new model but add in a new interaction term for the interaction between gender and gray matter volume. Extract all of the coefficients for the model. What have we learned?

# %%
# -------------------------------
# Question 7(c)
# -------------------------------
model3 <- lm(Flanker_Unadj ~ Gender*FS_Total_GM_Vol, data=hcp.d)
summary(model3)
cbind(coef(model3), confint(model3))

#We have learned that gray matter volume may be sigificantly related to raw flanker scores, 
#but we cannot conclude if there is or is not a significant relationship between gender 
#and raw flanker scores. Nor can we conclude if being male vs female does or does not 
#moderate the relationship between gray matter volume and raw flanker scores.  
#Also, adding gender and the interaction between gender and gray matter volume to our model
#only very minimally increases total variance explained (R-squared) from our
#base model (lm(formula = Flanker_Unadj ~ FS_Total_GM_Vol)) while notably decreasing the 
#F statistic, which indicates that when going from the base model to the current model, 
#we are increasing the variance/error in our model and thus decreasing our model fit.

##In sum, we learned that the parisimonious model is the best fitting model. ##
# Out:
# Call:
# lm(formula = Flanker_Unadj ~ Gender * FS_Total_GM_Vol, data = hcp.d)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -28.1278  -6.6040  -0.0247   6.4761  30.8430
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)              8.981e+01  5.357e+00  16.767  < 2e-16 ***
# GenderM                  5.340e+00  7.991e+00   0.668 0.504096
# FS_Total_GM_Vol          3.152e-05  8.262e-06   3.815 0.000144 ***
# GenderM:FS_Total_GM_Vol -6.822e-06  1.155e-05  -0.591 0.554802
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.868 on 1109 degrees of freedom
#   (93 observations deleted due to missingness)
# Multiple R-squared:  0.04369,	Adjusted R-squared:  0.0411
# F-statistic: 16.89 on 3 and 1109 DF,  p-value: 9.892e-11
#                                       2.5 %         97.5 %
# (Intercept)              8.981447e+01  7.930444e+01 1.003245e+02
# ...
